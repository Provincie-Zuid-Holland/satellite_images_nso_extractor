# %%
import rasterio
from rasterio.mask import mask
import geopandas as gpd
import os
import glob

def crop_tif_with_geojson(tif_path, geojson_path, output_path):
    try:
        # Open the GeoTIFF file
        with rasterio.open(tif_path) as src:
            # Read the GeoJSON file
            with open(geojson_path, 'r') as geojson_file:
                geojson_data = gpd.read_file(geojson_file)
                
                # Extract the geometry from the GeoJSON
                geom = geojson_data.geometry.values[0]
                
                # Perform the crop operation
                out_image, out_transform = mask(src, [geom], crop=True)
                out_meta = src.meta.copy()

                # Update the metadata for the cropped image
                out_meta.update({"driver": "GTiff",
                                 "height": out_image.shape[1],
                                 "width": out_image.shape[2],
                                 "transform": out_transform})

                # Write the cropped image to a new GeoTIFF file
                with rasterio.open(output_path, "w", **out_meta) as dest:
                    dest.write(out_image)

                print(f"Cropped GeoTIFF saved to {output_path}")
    except Exception as e:
        print(f"Error cropping GeoTIFF: {e}")

# %%
for afile in glob.glob("E:/data/nieuwkoopse_plassen/*.tif"):
    print(afile)

    crop_tif_with_geojson(afile,"C:/repos/satellite-images-nso/input_data/Schippersgat.geojson",afile.split(".tif")[0]+"schippersgat.tif")
# Out:
# E:/data/nieuwkoopse_plassen\20190302_113613_SV1-02_50cm_RD_11bit_RGBI_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20190302_113613_SV1-02_50cm_RD_11bit_RGBI_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20190409_111030_SV1-04_50cm_RD_11bit_RGBI_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20190409_111030_SV1-04_50cm_RD_11bit_RGBI_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20190523_111841_SV1-04_50cm_RD_11bit_RGBI_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20190523_111841_SV1-04_50cm_RD_11bit_RGBI_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20190629_113712_SV1-02_50cm_RD_11bit_RGBI_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20190629_113712_SV1-02_50cm_RD_11bit_RGBI_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20190629_113714_SV1-02_50cm_RD_11bit_RGBI_Woerden_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20190629_113714_SV1-02_50cm_RD_11bit_RGBI_Woerden_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20190806_110750_SV1-04_50cm_RD_11bit_RGBI_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20190806_110750_SV1-04_50cm_RD_11bit_RGBI_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20190820_113403_SV1-02_50cm_RD_11bit_RGBI_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20190820_113403_SV1-02_50cm_RD_11bit_RGBI_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20190826_111247_SV1-01_50cm_RD_11bit_RGBI_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20190826_111247_SV1-01_50cm_RD_11bit_RGBI_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20190918_110130_SV1-01_50cm_RD_11bit_RGBI_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20190918_110130_SV1-01_50cm_RD_11bit_RGBI_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20191003_113732_SV1-02_50cm_RD_11bit_RGBI_Nieuwveen_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20191003_113732_SV1-02_50cm_RD_11bit_RGBI_Nieuwveen_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20191108_110730_SV1-01_50cm_RD_11bit_RGBI_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20191108_110730_SV1-01_50cm_RD_11bit_RGBI_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20191108_110732_SV1-01_50cm_RD_11bit_RGBI_Oudewater_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20191108_110732_SV1-01_50cm_RD_11bit_RGBI_Oudewater_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20200628_114303_SV1-02_SV_RD_11bit_RGBI_50cm_Nieuwveen_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20200628_114303_SV1-02_SV_RD_11bit_RGBI_50cm_Nieuwveen_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20210423_111111_SV1-04_SV_RD_11bit_RGBI_50cm_Nieuwkoop_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20210423_111111_SV1-04_SV_RD_11bit_RGBI_50cm_Nieuwkoop_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20210617_111532_SV1-04_SV_RD_11bit_RGBI_50cm_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20210617_111532_SV1-04_SV_RD_11bit_RGBI_50cm_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20211129_103911_SV1-01_SV_RD_11bit_RGBI_50cm_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20211129_103911_SV1-01_SV_RD_11bit_RGBI_50cm_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20220316_110557_SV1-04_SV_RD_11bit_RGBI_50cm_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20220316_110557_SV1-04_SV_RD_11bit_RGBI_50cm_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20220318_114608_SV1-02_SV_RD_11bit_RGBI_50cm_Bodegraven_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20220318_114608_SV1-02_SV_RD_11bit_RGBI_50cm_Bodegraven_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20220712_110828_SV1-04_SV_RD_11bit_RGBI_50cm_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20220712_110828_SV1-04_SV_RD_11bit_RGBI_50cm_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20220803_105908_SV2-01_SV_RD_11bit_RGBI_50cm_Boskoop_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20220803_105908_SV2-01_SV_RD_11bit_RGBI_50cm_Boskoop_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20220811_110734_SV1-04_SV_RD_11bit_RGBI_50cm_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20220811_110734_SV1-04_SV_RD_11bit_RGBI_50cm_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20221012_104900_SV2-01_SV_RD_11bit_RGBI_50cm_Nieuwveen_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20221012_104900_SV2-01_SV_RD_11bit_RGBI_50cm_Nieuwveen_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20221012_104902_SV2-01_SV_RD_11bit_RGBI_50cm_Bodegraven_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20221012_104902_SV2-01_SV_RD_11bit_RGBI_50cm_Bodegraven_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20221025_111314_SV1-04_SV_RD_11bit_RGBI_50cm_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20221025_111314_SV1-04_SV_RD_11bit_RGBI_50cm_Mijdrecht_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20221025_111316_SV1-04_SV_RD_11bit_RGBI_50cm_Oudewater_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20221025_111316_SV1-04_SV_RD_11bit_RGBI_50cm_Oudewater_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20221201_105516_SV2-01_SV_RD_11bit_RGBI_50cm_Uithoorn_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20221201_105516_SV2-01_SV_RD_11bit_RGBI_50cm_Uithoorn_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20221201_105518_SV2-01_SV_RD_11bit_RGBI_50cm_Bodegraven_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20221201_105518_SV2-01_SV_RD_11bit_RGBI_50cm_Bodegraven_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20230330_104533_PNEO-04_1_42_30cm_RD_12bit_RGBNED_Nieuwkoop_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20230330_104533_PNEO-04_1_42_30cm_RD_12bit_RGBNED_Nieuwkoop_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20230601_105650_PNEO-04_1_1_30cm_RD_12bit_RGBNED_Oudewater_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Error cropping GeoTIFF: Input shapes do not overlap raster.
# E:/data/nieuwkoopse_plassen\20230603_104624_PNEO-03_1_1_30cm_RD_12bit_RGBNED_Uithoorn_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20230603_104624_PNEO-03_1_1_30cm_RD_12bit_RGBNED_Uithoorn_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
# E:/data/nieuwkoopse_plassen\20230905_105231_PNEO-03_1_1_30cm_RD_12bit_RGBNED_Uithoorn_Nieuwkoopse_Plassen_De_Haeck_cropped.tif
# Cropped GeoTIFF saved to E:/data/nieuwkoopse_plassen\20230905_105231_PNEO-03_1_1_30cm_RD_12bit_RGBNED_Uithoorn_Nieuwkoopse_Plassen_De_Haeck_croppedschippersgat.tif
